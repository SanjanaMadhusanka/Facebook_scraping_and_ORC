# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import pytesseract
# %matplotlib inline

# %%
imagePath = r'E:\Dataset\Second Data Set\Hotel Posts\Yara Galle fort\173753861_1416232325411989_2526540621172327056_n.jpg'

img = cv2.imread(imagePath, 0)
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

text = pytesseract.image_to_string(img)
fig = plt.figure(figsize = [10,10])
plt.imshow(img)

print(img.shape)
print(text)
# Out:
# (1068, 1043, 3)
# ATTRACTIVE
#
#
#
#
#
# Bed & Breakfast
#
# (2 Persons Net.)
#
# Room Only
#
# LKR 8,000
#
# (2 Persons Net.)

# %%
#converting image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
fig = plt.figure(figsize= [10,10])

text = pytesseract.image_to_string(gray)
print(text)
# Out:
# ATTRACTIVE
#
#
#
#
#
# Bed & Breakfast
#
# (2 Persons Net.)
#
# Room Only
#
# LKR 8,000
#
# (2 Persons Net.)

# %%
# file opened in append mode
file = open('Yara Galle fort.txt','a')
file.write(text)
file.close()
